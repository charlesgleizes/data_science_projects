# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style
# %matplotlib inline

from time import time

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image

# %%
path_csv = './x-ai_data.csv'
path_img = "./images/"
path_img_classified = "./images_classified/"

# %%
data_info = pd.read_csv(path_csv)
print(data_info.shape)
data_info.head(3)
# Out:
# (1999, 3)
#                               filename  class       split
# 0   silos_256-0-0--6-15--152-30320.png      0  validation
# 1  silos_256-0-0--6-15--1195-31353.png      0       train
# 2    silos_256-0-0--6-15-283-30628.png      0       train

# %% [raw]
# import os
#
# source = './images'
# destination = './images_classified/not_silos'
#
# # gather all files
# allfiles = data_info[data_info['class'] == 0].filename.values
#
# # iterate on all files to move them to destination folder
# for f in allfiles:
#     src_path = os.path.join(source, f)
#     dst_path = os.path.join(destination, f)
#     os.rename(src_path, dst_path)

# %% [raw]
# # To run once to split the pictures according to the expected classification
# import os
# import shutil
#
# source = './images'
# destination = './images_classified'
# config = {0: "silos", 1: "not_silos"}
# for i in [0,1]:
#     name = config.get(i)
#     # gather all files
#     allfiles = data_info[data_info['class'] == i].filename.values
#
#     # iterate on all files to move them to destination folder
#     for f in allfiles:
#         src_path = os.path.join(source, f)
#         dst_path = os.path.join(os.path.join(destination, name), f)
#         shutil.copyfile(src_path, dst_path)

# %%
# get the list of jpegs from sub image class folders
silos_imgs = [fn for fn in os.listdir(f'{path_img_classified}silos') if fn.endswith('.png')]
not_silos_imgs = [fn for fn in os.listdir(f'{path_img_classified}not_silos') if fn.endswith('.png')]

# randomly select 3 of each
select_silos = np.random.choice(silos_imgs, 3, replace = False)
select_not_silos = np.random.choice(not_silos_imgs, 3, replace = False)

# plotting 2 x 3 image matrix
fig = plt.figure(figsize = (12,8))
for i in range(6):
    if i < 3:
        fp = f'{path_img_classified}silos/{select_silos[i]}'
        label = 'SILOS'
    else:
        fp = f'{path_img_classified}not_silos/{select_not_silos[i-3]}'
        label = 'NOT SILOS'
    ax = fig.add_subplot(2, 3, i+1)
    
    # to plot without rescaling, remove target_size
    fn = image.load_img(fp, target_size = (256,256,3))
    plt.imshow(fn)
    plt.title(label)
    plt.axis('off')
plt.show()

# %%
imgs = [fn for fn in os.listdir(f'{path_img}') if fn.endswith('.png')]
silos_imgs = [fn for fn in os.listdir('images_classified/silos/') if fn.endswith('.png')]
not_silos_imgs = [fn for fn in os.listdir('images_classified/not_silos/') if fn.endswith('.png')]

# %%
# Check the number of files
print(f"Number of images : {len(imgs)}.")
print(f"Number of silos : {len(silos_imgs)}.")
print(f"Number of not_silos : {len(not_silos_imgs)}.")
# Out:
# Number of images : 3998.
# Number of silos : 999.
# Number of not_silos : 1000.

# %% [raw]
# # making n X m matrix
# def img2np(path, list_of_filename, size=(256, 256, 3)):
#     # iterating through each file
#     for fn in list_of_filename:
#         fp = path + fn
#         # print(fp)
#         current_image = image.load_img(fp, target_size=size)
#         # covert image to a matrix
#         img_ts = image.img_to_array(current_image)
#         # turn that into a vector / 1D array
#         img_ts = [img_ts.ravel()]
#         try:
#             # concatenate different images
#             full_mat = np.concatenate((full_mat, img_ts))
#         except UnboundLocalError:
#             # if not assigned yet, assign one
#             full_mat = img_ts
#     return full_mat

# %% [raw]
# # run it on our folders
# silos_images_2 = img2np(f'{path_img_classified}silos/', silos_imgs)

# %% [raw]
# # run it on our folders
# silos_images = img2np(f'{path_img_classified}silos/', silos_imgs)

# %% [raw]
# not_silos_images = img2np(f'{path_img_classified}not_silos/', not_silos_imgs)

# %% [raw]
# (silos_images_2 == silos_images).all()

# %% [raw]
# image_size = (256, 256)
# batch_size = 128
#
# train_ds = tf.keras.preprocessing.image_dataset_from_directory(
#     path_img_classified,
#     validation_split=0.2,
#     subset="training",
#     seed=1337,
#     image_size=image_size,
#     batch_size=batch_size,
# )
# val_ds = tf.keras.preprocessing.image_dataset_from_directory(
#     path_img_classified,
#     validation_split=0.2,
#     subset="validation",
#     seed=1337,
#     image_size=image_size,
#     batch_size=batch_size,
# )

# %%
BATCH_SIZE = 32 # Big enough to measure an F1-score
AUTOTUNE = tf.data.experimental.AUTOTUNE # Adapt preprocessing and prefetching dynamically
SHUFFLE_BUFFER_SIZE = 1024 # Shuffle the training data by a chunck of 1024 observations
CHANNELS = 3
IMG_SIZE = 256

# %%
from tensorflow.keras.utils import img_to_array, array_to_img
def crop_add(im):
    array = img_to_array(im)
    if tf.random.uniform(()) > 0.5:
        array_bottom = array[:128,:,:].copy()
        array[:128,:,:] = array[128:,:,:]
        array[128:,:,:] = array_bottom
    im_crop = array_to_img(array)
    return im_crop

# %%
def parse_function_train(filename, label, seed=(1, 2)):
    """Function that returns a tuple of normalized image array and labels array.
    Args:
        filename: string representing path to image
        label: 0/1 one-dimensional array of size N_LABELS
    """
    # Read an image from a file
    image_string = tf.io.read_file(filename)
    # Decode it into a dense vector
    image_decoded = tf.image.decode_jpeg(image_string, channels=CHANNELS)
    # Resize it to fixed shape
    image_resized = tf.image.resize(image_decoded, [IMG_SIZE, IMG_SIZE])
    # Normalize it from [0, 255] to [0.0, 1.0]
    image_normalized = image_resized / 255.0
    
    # Random brightness.
    #image_augmented1 = tf.image.stateless_random_brightness(
    #    image_normalized, max_delta=0.2, seed=seed)
    
    # image_augmented = tf.image.stateless_random_contrast(
    #     image_augmented, lower=0.4, upper=0.6, seed=seed)
    # image_augmented = tf.image.stateless_random_saturation(
    #     image_augmented, lower=0.4, upper=0.6, seed=seed)
    # image_augmented = tf.image.stateless_random_jpeg_quality(
    #     image_augmented, min_jpeg_quality=75, max_jpeg_quality=100, seed=seed)
    #image_augmented2 = tf.image.stateless_random_flip_left_right(image_normalized, seed=seed)
    #image_augmented3 = tf.image.stateless_random_flip_up_down(image_normalized, seed)
    
    data_augmentation = tf.keras.Sequential([
      layers.RandomFlip(mode="horizontal_and_vertical", seed=seed),
      layers.RandomRotation(factor=0.2, seed=seed)])
    
    image_augmented1 = data_augmentation(image_normalized)
    image_augmented2 = data_augmentation(image_normalized)
    image_augmented3 = data_augmentation(image_normalized)
    image_augmented4 = data_augmentation(image_normalized)

    
    return [(image_normalized, label), 
            (image_augmented1, label), 
            (image_augmented2, label), 
            (image_augmented3, label), 
            (image_augmented4, label)]

# %%
def parse_function(filename, label, seed=(1, 2)):
    """
    Function that returns a tuple of normalized image array and labels array.
    This parse function doesn't shuffle nor does data augmentation. 
    It is thus meant for the validation dataset.
    Args:
        filename: string representing path to image
        label: 0/1 one-dimensional array of size N_LABELS
    """
    # Read an image from a file
    image_string = tf.io.read_file(filename)
    # Decode it into a dense vector
    image_decoded = tf.image.decode_jpeg(image_string, channels=CHANNELS)
    # Resize it to fixed shape
    image_resized = tf.image.resize(image_decoded, [IMG_SIZE, IMG_SIZE])
    # Normalize it from [0, 255] to [0.0, 1.0]
    image_normalized = image_resized / 255.0
    
    return image_normalized, label

# %%
def create_dataset(filenames, labels, is_training=True):
    """
    Load and parse dataset.
    Args:
        filenames: list of image paths
        labels: numpy array of shape (BATCH_SIZE, N_LABELS)
        is_training: boolean to indicate training mode
    """
    # Create a first dataset of file paths and labels
    dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))

    if is_training == True:
        # Parse and preprocess observations in parallel
        dataset = dataset.map(parse_function_train, num_parallel_calls=AUTOTUNE)

        names = []
        labels = []
        for group_image in dataset:
            for element in group_image: 
                names += [element[0]]
                labels += [element[1]]
        dataset = tf.data.Dataset.from_tensor_slices((names, labels))
        
        # This is a small dataset, only load it once, and keep it in memory.
        dataset = dataset.cache()
        # Shuffle the data each buffer size
        dataset = dataset.shuffle(buffer_size=len(list(dataset)))
    else:
        # Parse and preprocess observations in parallel
        dataset = dataset.map(parse_function, num_parallel_calls=AUTOTUNE)
        
        # This is a small dataset, only load it once, and keep it in memory.
        dataset = dataset.cache()
        
    # Batch the data for multiple steps
    dataset = dataset.batch(BATCH_SIZE)
    # Fetch batches in the background while the model is training.
    dataset = dataset.prefetch(buffer_size=AUTOTUNE)
    
    return dataset

# %%
X_train = data_info[data_info['split'] == 'train'].filename.values
y_train = data_info[data_info['split'] == 'train']['class'].values

X_val = data_info[data_info['split'] == 'validation'].filename.values
y_val = data_info[data_info['split'] == 'validation']['class'].values

# %%
X_train = [os.path.join(path_img, str(f)) for f in X_train]
X_val = [os.path.join(path_img, str(f)) for f in X_val]

# %%
pd.DataFrame(X_train).head(3)
# Out:
#                                               0
# 0  ./images/silos_256-0-0--6-15--1195-31353.png
# 1    ./images/silos_256-0-0--6-15-283-30628.png
# 2   ./images/silos_256-0-0--6-15--404-30011.png

# %%
start = time()
train_ds = create_dataset(X_train, y_train, is_training=True)
val_ds = create_dataset(X_val, y_val, is_training=False)
print(round(time()-start, 2))
# Out:
# 18.67

# %%
number_of_train_images = len(y_train)*5
print(f"Actual length: {number_of_train_images}.")
# Out:
# Actual length: 6995.

# %%
b = (len(list(train_ds))-1)*32
c = len(list(train_ds))*32
print(f"Actual length between {b} and {c} :")
print((number_of_train_images > b) and (number_of_train_images < c))
# Out:
# Actual length between 6976 and 7008 :
# True

# %%
for f, l in train_ds.take(1):
    print("Shape of features array:", f.numpy().shape)
    print("Shape of labels array:", l.numpy().shape)
# Out:
# Shape of features array: (32, 256, 256, 3)
# Shape of labels array: (32,)

# %% [raw]
# def make_model(input_shape, num_classes):
#     inputs = keras.Input(shape=input_shape)
#
#     # Entry block
#     x = layers.Rescaling(1.0 / 255)(inputs)
#     x = layers.Conv2D(128, 3, strides=2, padding="same")(x)
#     x = layers.BatchNormalization()(x)
#     x = layers.Activation("relu")(x)
#
#     previous_block_activation = x  # Set aside residual
#
#     for size in [256]:#[256, 512, 728]:
#         # x = layers.Activation("relu")(x)
#         # x = layers.SeparableConv2D(size, 3, padding="same")(x)
#         # x = layers.BatchNormalization()(x)
#
#         x = layers.Activation("relu")(x)
#         x = layers.SeparableConv2D(size, 3, padding="same")(x)
#         x = layers.BatchNormalization()(x)
#
#         x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
#
#         # Project residual
#         residual = layers.Conv2D(size, 1, strides=2, padding="same")(
#             previous_block_activation
#         )
#         x = layers.add([x, residual])  # Add back residual
#         previous_block_activation = x  # Set aside next residual
#
#     x = layers.SeparableConv2D(1024, 3, padding="same")(x)
#     x = layers.BatchNormalization()(x)
#     x = layers.Activation("relu")(x)
#
#     x = layers.GlobalAveragePooling2D()(x)
#     if num_classes == 2:
#         activation = "sigmoid"
#         units = 1
#     else:
#         activation = "softmax"
#         units = num_classes
#
#     x = layers.Dropout(0.5)(x)
#     outputs = layers.Dense(units, activation=activation)(x)
#     return keras.Model(inputs, outputs)

# %% [raw]
# model = make_model(input_shape=(IMG_SIZE, IMG_SIZE, CHANNELS), num_classes=2)
# #keras.utils.plot_model(model, show_shapes=True)

# %% [raw]
# model.compile(
#     optimizer=keras.optimizers.Adam(1e-3),
#     loss="binary_crossentropy",
#     metrics=["accuracy"],
# )

# %%
from tensorflow.keras.optimizers import RMSprop, Adam

# %%
LR = 0.0001
# BATCH_SIZE = 128

# %%
model = tf.keras.models.Sequential([ 
  
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, CHANNELS)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_regularizer='l2'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_regularizer='l2'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Flatten(),     
    tf.keras.layers.Dense(512, activation='relu', kernel_regularizer='l2'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(1, activation='sigmoid')])

model.compile(optimizer=RMSprop(learning_rate=LR), loss='binary_crossentropy', metrics=[tf.keras.metrics.AUC(), "accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 254, 254, 16)      448
#
#  max_pooling2d_9 (MaxPooling  (None, 127, 127, 16)     0
#  2D)
#
#  dropout_12 (Dropout)        (None, 127, 127, 16)      0
#
#  conv2d_10 (Conv2D)          (None, 125, 125, 32)      4640
#
#  max_pooling2d_10 (MaxPoolin  (None, 62, 62, 32)       0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 62, 62, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 60, 60, 64)        18496
#
#  max_pooling2d_11 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 30, 30, 64)        0
#
#  flatten_3 (Flatten)         (None, 57600)             0
#
#  dense_6 (Dense)             (None, 512)               29491712
#
#  dropout_15 (Dropout)        (None, 512)               0
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_7 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 29,517,857
# Trainable params: 29,516,833
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
EPOCHS = 100

# %%
start = time()
history = model.fit(train_ds,
                    epochs=EPOCHS,
                    validation_data=val_ds,
                    callbacks=[
                            tf.keras.callbacks.ModelCheckpoint(
                                os.path.join('test_models/', 
                                             'model_Camille_data_augmented_3/epoch_{epoch:02d}_val_loss_{val_loss:.4f}.h5'),
                                monitor='val_auc', save_best_only=True
                            )
                    ]
                   )

print(f'Training took {round(time()-start, 2)} sec')
# Out:
# Epoch 1/100
# 219/219 [==============================] - ETA: 0s - loss: 5.4565 - auc_3: 0.5852 - accuracy: 0.5660WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 7s 23ms/step - loss: 5.4565 - auc_3: 0.5852 - accuracy: 0.5660 - val_loss: 2.9447 - val_auc_3: 0.7096 - val_accuracy: 0.5150
# Epoch 2/100
# 217/219 [============================>.] - ETA: 0s - loss: 2.0857 - auc_3: 0.6057 - accuracy: 0.5821WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 2.0828 - auc_3: 0.6059 - accuracy: 0.5824 - val_loss: 2.1004 - val_auc_3: 0.6221 - val_accuracy: 0.5150
# Epoch 3/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.6226 - auc_3: 0.6208 - accuracy: 0.5900WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 19ms/step - loss: 1.6207 - auc_3: 0.6216 - accuracy: 0.5910 - val_loss: 1.7162 - val_auc_3: 0.6641 - val_accuracy: 0.5150
# Epoch 4/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.4454 - auc_3: 0.6265 - accuracy: 0.5965WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 1.4439 - auc_3: 0.6270 - accuracy: 0.5971 - val_loss: 1.4679 - val_auc_3: 0.3939 - val_accuracy: 0.5150
# Epoch 5/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.3224 - auc_3: 0.6536 - accuracy: 0.6205WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 1.3220 - auc_3: 0.6537 - accuracy: 0.6202 - val_loss: 1.2595 - val_auc_3: 0.3728 - val_accuracy: 0.5150
# Epoch 6/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.1842 - auc_3: 0.7037 - accuracy: 0.6616WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 1.1838 - auc_3: 0.7036 - accuracy: 0.6612 - val_loss: 1.1345 - val_auc_3: 0.7127 - val_accuracy: 0.6175
# Epoch 7/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.0629 - auc_3: 0.7481 - accuracy: 0.6928WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 1.0625 - auc_3: 0.7481 - accuracy: 0.6928 - val_loss: 1.0948 - val_auc_3: 0.5302 - val_accuracy: 0.5125
# Epoch 8/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.9059 - auc_3: 0.8062 - accuracy: 0.7368WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 19ms/step - loss: 0.9062 - auc_3: 0.8059 - accuracy: 0.7368 - val_loss: 0.9791 - val_auc_3: 0.7412 - val_accuracy: 0.6550
# Epoch 9/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.7783 - auc_3: 0.8505 - accuracy: 0.7729WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.7784 - auc_3: 0.8503 - accuracy: 0.7730 - val_loss: 0.8703 - val_auc_3: 0.8481 - val_accuracy: 0.6425
# Epoch 10/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.7085 - auc_3: 0.8669 - accuracy: 0.7919WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.7076 - auc_3: 0.8673 - accuracy: 0.7927 - val_loss: 0.8012 - val_auc_3: 0.8515 - val_accuracy: 0.6575
# Epoch 11/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.6551 - auc_3: 0.8839 - accuracy: 0.8065WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.6547 - auc_3: 0.8841 - accuracy: 0.8070 - val_loss: 0.7344 - val_auc_3: 0.8884 - val_accuracy: 0.7100
# Epoch 12/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.6339 - auc_3: 0.8868 - accuracy: 0.8083WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.6332 - auc_3: 0.8872 - accuracy: 0.8084 - val_loss: 0.6727 - val_auc_3: 0.9127 - val_accuracy: 0.7575
# Epoch 13/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.5971 - auc_3: 0.9003 - accuracy: 0.8243WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 19ms/step - loss: 0.5974 - auc_3: 0.9001 - accuracy: 0.8240 - val_loss: 0.6302 - val_auc_3: 0.9145 - val_accuracy: 0.8025
# Epoch 14/100
# 219/219 [==============================] - ETA: 0s - loss: 0.5821 - auc_3: 0.9024 - accuracy: 0.8252WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5821 - auc_3: 0.9024 - accuracy: 0.8252 - val_loss: 0.6367 - val_auc_3: 0.8847 - val_accuracy: 0.7650
# Epoch 15/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.5636 - auc_3: 0.9090 - accuracy: 0.8311WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5631 - auc_3: 0.9092 - accuracy: 0.8310 - val_loss: 0.5994 - val_auc_3: 0.9177 - val_accuracy: 0.8050
# Epoch 16/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.5518 - auc_3: 0.9120 - accuracy: 0.8373WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5518 - auc_3: 0.9119 - accuracy: 0.8370 - val_loss: 0.5872 - val_auc_3: 0.9017 - val_accuracy: 0.8150
# Epoch 17/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.5362 - auc_3: 0.9172 - accuracy: 0.8452WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5366 - auc_3: 0.9170 - accuracy: 0.8446 - val_loss: 0.5394 - val_auc_3: 0.9309 - val_accuracy: 0.8600
# Epoch 18/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.5417 - auc_3: 0.9133 - accuracy: 0.8335WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5422 - auc_3: 0.9131 - accuracy: 0.8335 - val_loss: 0.5581 - val_auc_3: 0.9269 - val_accuracy: 0.8500
# Epoch 19/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.5344 - auc_3: 0.9148 - accuracy: 0.8400WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5343 - auc_3: 0.9149 - accuracy: 0.8402 - val_loss: 0.5419 - val_auc_3: 0.9250 - val_accuracy: 0.8425
# Epoch 20/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.5264 - auc_3: 0.9178 - accuracy: 0.8455WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5271 - auc_3: 0.9174 - accuracy: 0.8449 - val_loss: 0.5498 - val_auc_3: 0.9166 - val_accuracy: 0.8500
# Epoch 21/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.5136 - auc_3: 0.9226 - accuracy: 0.8458WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5154 - auc_3: 0.9223 - accuracy: 0.8455 - val_loss: 0.5281 - val_auc_3: 0.9352 - val_accuracy: 0.8525
# Epoch 22/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.5147 - auc_3: 0.9214 - accuracy: 0.8475WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5141 - auc_3: 0.9217 - accuracy: 0.8476 - val_loss: 0.4987 - val_auc_3: 0.9408 - val_accuracy: 0.8700
# Epoch 23/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.5109 - auc_3: 0.9214 - accuracy: 0.8486WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.5106 - auc_3: 0.9214 - accuracy: 0.8489 - val_loss: 0.5327 - val_auc_3: 0.9154 - val_accuracy: 0.8475
# Epoch 24/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4974 - auc_3: 0.9259 - accuracy: 0.8505WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4991 - auc_3: 0.9253 - accuracy: 0.8495 - val_loss: 0.5189 - val_auc_3: 0.9299 - val_accuracy: 0.8475
# Epoch 25/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4938 - auc_3: 0.9275 - accuracy: 0.8528WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4939 - auc_3: 0.9275 - accuracy: 0.8528 - val_loss: 0.5666 - val_auc_3: 0.9095 - val_accuracy: 0.8200
# Epoch 26/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4859 - auc_3: 0.9284 - accuracy: 0.8554WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4859 - auc_3: 0.9284 - accuracy: 0.8553 - val_loss: 0.5397 - val_auc_3: 0.9124 - val_accuracy: 0.8375
# Epoch 27/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4920 - auc_3: 0.9255 - accuracy: 0.8546WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4935 - auc_3: 0.9250 - accuracy: 0.8540 - val_loss: 0.5285 - val_auc_3: 0.9256 - val_accuracy: 0.8375
# Epoch 28/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4840 - auc_3: 0.9288 - accuracy: 0.8567WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4833 - auc_3: 0.9291 - accuracy: 0.8568 - val_loss: 0.4579 - val_auc_3: 0.9468 - val_accuracy: 0.8750
# Epoch 29/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4807 - auc_3: 0.9299 - accuracy: 0.8584WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4802 - auc_3: 0.9301 - accuracy: 0.8589 - val_loss: 0.4824 - val_auc_3: 0.9418 - val_accuracy: 0.8550
# Epoch 30/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4815 - auc_3: 0.9301 - accuracy: 0.8580WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4813 - auc_3: 0.9302 - accuracy: 0.8580 - val_loss: 0.4657 - val_auc_3: 0.9433 - val_accuracy: 0.8675
# Epoch 31/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4813 - auc_3: 0.9289 - accuracy: 0.8563WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4815 - auc_3: 0.9288 - accuracy: 0.8559 - val_loss: 0.5051 - val_auc_3: 0.9235 - val_accuracy: 0.8450
# Epoch 32/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4783 - auc_3: 0.9297 - accuracy: 0.8544WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4786 - auc_3: 0.9296 - accuracy: 0.8538 - val_loss: 0.5095 - val_auc_3: 0.9476 - val_accuracy: 0.8375
# Epoch 33/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4711 - auc_3: 0.9315 - accuracy: 0.8606WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4705 - auc_3: 0.9318 - accuracy: 0.8609 - val_loss: 0.4527 - val_auc_3: 0.9445 - val_accuracy: 0.8625
# Epoch 34/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4682 - auc_3: 0.9316 - accuracy: 0.8583WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4678 - auc_3: 0.9318 - accuracy: 0.8585 - val_loss: 0.4605 - val_auc_3: 0.9429 - val_accuracy: 0.8725
# Epoch 35/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4638 - auc_3: 0.9335 - accuracy: 0.8610WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4629 - auc_3: 0.9339 - accuracy: 0.8613 - val_loss: 0.5120 - val_auc_3: 0.9438 - val_accuracy: 0.8375
# Epoch 36/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4711 - auc_3: 0.9302 - accuracy: 0.8547WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4722 - auc_3: 0.9298 - accuracy: 0.8543 - val_loss: 0.4617 - val_auc_3: 0.9451 - val_accuracy: 0.8775
# Epoch 37/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4640 - auc_3: 0.9319 - accuracy: 0.8643WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4646 - auc_3: 0.9316 - accuracy: 0.8636 - val_loss: 0.5057 - val_auc_3: 0.9262 - val_accuracy: 0.8425
# Epoch 38/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4559 - auc_3: 0.9350 - accuracy: 0.8636WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4567 - auc_3: 0.9346 - accuracy: 0.8628 - val_loss: 0.4962 - val_auc_3: 0.9313 - val_accuracy: 0.8400
# Epoch 39/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4525 - auc_3: 0.9370 - accuracy: 0.8651WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4524 - auc_3: 0.9370 - accuracy: 0.8652 - val_loss: 0.4936 - val_auc_3: 0.9415 - val_accuracy: 0.8275
# Epoch 40/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4513 - auc_3: 0.9368 - accuracy: 0.8669WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4508 - auc_3: 0.9371 - accuracy: 0.8668 - val_loss: 0.4437 - val_auc_3: 0.9436 - val_accuracy: 0.8800
# Epoch 41/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4576 - auc_3: 0.9337 - accuracy: 0.8586WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4571 - auc_3: 0.9339 - accuracy: 0.8589 - val_loss: 0.4978 - val_auc_3: 0.9453 - val_accuracy: 0.8275
# Epoch 42/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4509 - auc_3: 0.9368 - accuracy: 0.8677WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4508 - auc_3: 0.9367 - accuracy: 0.8678 - val_loss: 0.4598 - val_auc_3: 0.9480 - val_accuracy: 0.8500
# Epoch 43/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4419 - auc_3: 0.9403 - accuracy: 0.8648WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4413 - auc_3: 0.9405 - accuracy: 0.8653 - val_loss: 0.4409 - val_auc_3: 0.9502 - val_accuracy: 0.8675
# Epoch 44/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4523 - auc_3: 0.9363 - accuracy: 0.8620WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4522 - auc_3: 0.9363 - accuracy: 0.8620 - val_loss: 0.4636 - val_auc_3: 0.9388 - val_accuracy: 0.8625
# Epoch 45/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4441 - auc_3: 0.9384 - accuracy: 0.8652WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4437 - auc_3: 0.9386 - accuracy: 0.8653 - val_loss: 0.4450 - val_auc_3: 0.9461 - val_accuracy: 0.8700
# Epoch 46/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4447 - auc_3: 0.9380 - accuracy: 0.8632WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4448 - auc_3: 0.9380 - accuracy: 0.8633 - val_loss: 0.4507 - val_auc_3: 0.9451 - val_accuracy: 0.8700
# Epoch 47/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4381 - auc_3: 0.9400 - accuracy: 0.8724WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4400 - auc_3: 0.9395 - accuracy: 0.8721 - val_loss: 0.4820 - val_auc_3: 0.9481 - val_accuracy: 0.8525
# Epoch 48/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4458 - auc_3: 0.9375 - accuracy: 0.8684WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4453 - auc_3: 0.9377 - accuracy: 0.8688 - val_loss: 0.4643 - val_auc_3: 0.9410 - val_accuracy: 0.8650
# Epoch 49/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4353 - auc_3: 0.9414 - accuracy: 0.8711WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4365 - auc_3: 0.9409 - accuracy: 0.8703 - val_loss: 0.4755 - val_auc_3: 0.9351 - val_accuracy: 0.8550
# Epoch 50/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4394 - auc_3: 0.9390 - accuracy: 0.8675WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4394 - auc_3: 0.9390 - accuracy: 0.8676 - val_loss: 0.4598 - val_auc_3: 0.9480 - val_accuracy: 0.8625
# Epoch 51/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4291 - auc_3: 0.9434 - accuracy: 0.8692WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4298 - auc_3: 0.9431 - accuracy: 0.8690 - val_loss: 0.4756 - val_auc_3: 0.9323 - val_accuracy: 0.8500
# Epoch 52/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4425 - auc_3: 0.9374 - accuracy: 0.8666WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4428 - auc_3: 0.9372 - accuracy: 0.8660 - val_loss: 0.4316 - val_auc_3: 0.9453 - val_accuracy: 0.8700
# Epoch 53/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4296 - auc_3: 0.9421 - accuracy: 0.8720WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4316 - auc_3: 0.9417 - accuracy: 0.8716 - val_loss: 0.4786 - val_auc_3: 0.9242 - val_accuracy: 0.8750
# Epoch 54/100
# 219/219 [==============================] - ETA: 0s - loss: 0.4308 - auc_3: 0.9424 - accuracy: 0.8713WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4308 - auc_3: 0.9424 - accuracy: 0.8713 - val_loss: 0.4485 - val_auc_3: 0.9397 - val_accuracy: 0.8550
# Epoch 55/100
# 219/219 [==============================] - ETA: 0s - loss: 0.4272 - auc_3: 0.9429 - accuracy: 0.8712WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4272 - auc_3: 0.9429 - accuracy: 0.8712 - val_loss: 0.4848 - val_auc_3: 0.9358 - val_accuracy: 0.8500
# Epoch 56/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4324 - auc_3: 0.9408 - accuracy: 0.8711WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4326 - auc_3: 0.9408 - accuracy: 0.8708 - val_loss: 0.4568 - val_auc_3: 0.9451 - val_accuracy: 0.8750
# Epoch 57/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4256 - auc_3: 0.9428 - accuracy: 0.8730WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4261 - auc_3: 0.9426 - accuracy: 0.8725 - val_loss: 0.4416 - val_auc_3: 0.9415 - val_accuracy: 0.8650
# Epoch 58/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4325 - auc_3: 0.9402 - accuracy: 0.8687WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4322 - auc_3: 0.9403 - accuracy: 0.8688 - val_loss: 0.4541 - val_auc_3: 0.9334 - val_accuracy: 0.8625
# Epoch 59/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4244 - auc_3: 0.9433 - accuracy: 0.8736WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4256 - auc_3: 0.9428 - accuracy: 0.8729 - val_loss: 0.4412 - val_auc_3: 0.9398 - val_accuracy: 0.8625
# Epoch 60/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4209 - auc_3: 0.9450 - accuracy: 0.8704WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4209 - auc_3: 0.9449 - accuracy: 0.8706 - val_loss: 0.4647 - val_auc_3: 0.9458 - val_accuracy: 0.8525
# Epoch 61/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4290 - auc_3: 0.9414 - accuracy: 0.8701WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4288 - auc_3: 0.9415 - accuracy: 0.8702 - val_loss: 0.4405 - val_auc_3: 0.9388 - val_accuracy: 0.8650
# Epoch 62/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4307 - auc_3: 0.9401 - accuracy: 0.8747WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4306 - auc_3: 0.9402 - accuracy: 0.8748 - val_loss: 0.4917 - val_auc_3: 0.9338 - val_accuracy: 0.8350
# Epoch 63/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4203 - auc_3: 0.9444 - accuracy: 0.8710WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4212 - auc_3: 0.9441 - accuracy: 0.8706 - val_loss: 0.4393 - val_auc_3: 0.9391 - val_accuracy: 0.8625
# Epoch 64/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4209 - auc_3: 0.9443 - accuracy: 0.8744WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 19ms/step - loss: 0.4230 - auc_3: 0.9435 - accuracy: 0.8736 - val_loss: 0.4529 - val_auc_3: 0.9367 - val_accuracy: 0.8775
# Epoch 65/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4264 - auc_3: 0.9426 - accuracy: 0.8677WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4278 - auc_3: 0.9420 - accuracy: 0.8672 - val_loss: 0.4858 - val_auc_3: 0.9425 - val_accuracy: 0.8450
# Epoch 66/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4176 - auc_3: 0.9456 - accuracy: 0.8736WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4182 - auc_3: 0.9454 - accuracy: 0.8733 - val_loss: 0.4397 - val_auc_3: 0.9394 - val_accuracy: 0.8550
# Epoch 67/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4137 - auc_3: 0.9469 - accuracy: 0.8802WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4140 - auc_3: 0.9468 - accuracy: 0.8799 - val_loss: 0.5091 - val_auc_3: 0.9078 - val_accuracy: 0.8200
# Epoch 68/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4160 - auc_3: 0.9456 - accuracy: 0.8727WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4166 - auc_3: 0.9454 - accuracy: 0.8725 - val_loss: 0.4883 - val_auc_3: 0.9177 - val_accuracy: 0.8475
# Epoch 69/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4146 - auc_3: 0.9465 - accuracy: 0.8816WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4156 - auc_3: 0.9462 - accuracy: 0.8813 - val_loss: 0.5940 - val_auc_3: 0.9244 - val_accuracy: 0.7825
# Epoch 70/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4156 - auc_3: 0.9453 - accuracy: 0.8759WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4152 - auc_3: 0.9455 - accuracy: 0.8762 - val_loss: 0.4631 - val_auc_3: 0.9273 - val_accuracy: 0.8375
# Epoch 71/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4217 - auc_3: 0.9436 - accuracy: 0.8713WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4224 - auc_3: 0.9433 - accuracy: 0.8711 - val_loss: 0.4973 - val_auc_3: 0.9310 - val_accuracy: 0.8500
# Epoch 72/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4138 - auc_3: 0.9466 - accuracy: 0.8774WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4136 - auc_3: 0.9466 - accuracy: 0.8776 - val_loss: 0.5095 - val_auc_3: 0.9412 - val_accuracy: 0.8300
# Epoch 73/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4160 - auc_3: 0.9454 - accuracy: 0.8753WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4166 - auc_3: 0.9452 - accuracy: 0.8746 - val_loss: 0.4381 - val_auc_3: 0.9381 - val_accuracy: 0.8750
# Epoch 74/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4078 - auc_3: 0.9484 - accuracy: 0.8766WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4078 - auc_3: 0.9484 - accuracy: 0.8765 - val_loss: 0.4470 - val_auc_3: 0.9442 - val_accuracy: 0.8625
# Epoch 75/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4140 - auc_3: 0.9459 - accuracy: 0.8773WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4130 - auc_3: 0.9463 - accuracy: 0.8779 - val_loss: 0.4627 - val_auc_3: 0.9266 - val_accuracy: 0.8525
# Epoch 76/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4041 - auc_3: 0.9493 - accuracy: 0.8831WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4045 - auc_3: 0.9492 - accuracy: 0.8829 - val_loss: 0.4496 - val_auc_3: 0.9382 - val_accuracy: 0.8675
# Epoch 77/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4102 - auc_3: 0.9474 - accuracy: 0.8770WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4112 - auc_3: 0.9470 - accuracy: 0.8771 - val_loss: 0.4675 - val_auc_3: 0.9508 - val_accuracy: 0.8525
# Epoch 78/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4088 - auc_3: 0.9477 - accuracy: 0.8754WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4085 - auc_3: 0.9478 - accuracy: 0.8759 - val_loss: 0.5085 - val_auc_3: 0.9260 - val_accuracy: 0.8350
# Epoch 79/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4124 - auc_3: 0.9462 - accuracy: 0.8773WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4117 - auc_3: 0.9464 - accuracy: 0.8778 - val_loss: 0.4645 - val_auc_3: 0.9257 - val_accuracy: 0.8475
# Epoch 80/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4137 - auc_3: 0.9453 - accuracy: 0.8751WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4141 - auc_3: 0.9452 - accuracy: 0.8755 - val_loss: 0.4654 - val_auc_3: 0.9327 - val_accuracy: 0.8475
# Epoch 81/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4137 - auc_3: 0.9458 - accuracy: 0.8756WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4136 - auc_3: 0.9458 - accuracy: 0.8761 - val_loss: 0.4421 - val_auc_3: 0.9358 - val_accuracy: 0.8575
# Epoch 82/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4088 - auc_3: 0.9476 - accuracy: 0.8779WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4110 - auc_3: 0.9468 - accuracy: 0.8762 - val_loss: 0.4926 - val_auc_3: 0.9078 - val_accuracy: 0.8500
# Epoch 83/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4072 - auc_3: 0.9477 - accuracy: 0.8796WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4075 - auc_3: 0.9475 - accuracy: 0.8793 - val_loss: 0.4459 - val_auc_3: 0.9357 - val_accuracy: 0.8600
# Epoch 84/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4052 - auc_3: 0.9487 - accuracy: 0.8762WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4058 - auc_3: 0.9485 - accuracy: 0.8759 - val_loss: 0.5218 - val_auc_3: 0.9328 - val_accuracy: 0.8400
# Epoch 85/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4053 - auc_3: 0.9487 - accuracy: 0.8789WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4050 - auc_3: 0.9488 - accuracy: 0.8793 - val_loss: 0.4466 - val_auc_3: 0.9422 - val_accuracy: 0.8575
# Epoch 86/100
# 219/219 [==============================] - ETA: 0s - loss: 0.4092 - auc_3: 0.9477 - accuracy: 0.8799WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4092 - auc_3: 0.9477 - accuracy: 0.8799 - val_loss: 0.4334 - val_auc_3: 0.9380 - val_accuracy: 0.8725
# Epoch 87/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4126 - auc_3: 0.9459 - accuracy: 0.8780WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4126 - auc_3: 0.9459 - accuracy: 0.8781 - val_loss: 0.4420 - val_auc_3: 0.9349 - val_accuracy: 0.8575
# Epoch 88/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4006 - auc_3: 0.9510 - accuracy: 0.8773WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4009 - auc_3: 0.9509 - accuracy: 0.8769 - val_loss: 0.4890 - val_auc_3: 0.9379 - val_accuracy: 0.8450
# Epoch 89/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4119 - auc_3: 0.9459 - accuracy: 0.8717WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4124 - auc_3: 0.9457 - accuracy: 0.8713 - val_loss: 0.4290 - val_auc_3: 0.9457 - val_accuracy: 0.8650
# Epoch 90/100
# 219/219 [==============================] - ETA: 0s - loss: 0.3977 - auc_3: 0.9511 - accuracy: 0.8845WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.3977 - auc_3: 0.9511 - accuracy: 0.8845 - val_loss: 0.4535 - val_auc_3: 0.9338 - val_accuracy: 0.8525
# Epoch 91/100
# 219/219 [==============================] - ETA: 0s - loss: 0.4067 - auc_3: 0.9472 - accuracy: 0.8778WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.4067 - auc_3: 0.9472 - accuracy: 0.8778 - val_loss: 0.4611 - val_auc_3: 0.9313 - val_accuracy: 0.8625
# Epoch 92/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.3995 - auc_3: 0.9499 - accuracy: 0.8812WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3996 - auc_3: 0.9498 - accuracy: 0.8809 - val_loss: 0.4949 - val_auc_3: 0.9436 - val_accuracy: 0.8375
# Epoch 93/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.3956 - auc_3: 0.9506 - accuracy: 0.8838WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3956 - auc_3: 0.9507 - accuracy: 0.8841 - val_loss: 0.4350 - val_auc_3: 0.9388 - val_accuracy: 0.8650
# Epoch 94/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4033 - auc_3: 0.9482 - accuracy: 0.8864WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4027 - auc_3: 0.9484 - accuracy: 0.8866 - val_loss: 0.4648 - val_auc_3: 0.9313 - val_accuracy: 0.8525
# Epoch 95/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.3965 - auc_3: 0.9505 - accuracy: 0.8809WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.3962 - auc_3: 0.9507 - accuracy: 0.8809 - val_loss: 0.4632 - val_auc_3: 0.9412 - val_accuracy: 0.8725
# Epoch 96/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.3976 - auc_3: 0.9492 - accuracy: 0.8767WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3978 - auc_3: 0.9491 - accuracy: 0.8766 - val_loss: 0.5884 - val_auc_3: 0.9370 - val_accuracy: 0.8000
# Epoch 97/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4049 - auc_3: 0.9468 - accuracy: 0.8776WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.4045 - auc_3: 0.9470 - accuracy: 0.8775 - val_loss: 0.5219 - val_auc_3: 0.9359 - val_accuracy: 0.8275
# Epoch 98/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.3927 - auc_3: 0.9515 - accuracy: 0.8816WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 5s 21ms/step - loss: 0.3928 - auc_3: 0.9514 - accuracy: 0.8818 - val_loss: 0.4593 - val_auc_3: 0.9481 - val_accuracy: 0.8775
# Epoch 99/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.3933 - auc_3: 0.9510 - accuracy: 0.8845WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3924 - auc_3: 0.9513 - accuracy: 0.8851 - val_loss: 0.4804 - val_auc_3: 0.9347 - val_accuracy: 0.8525
# Epoch 100/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.4000 - auc_3: 0.9485 - accuracy: 0.8790WARNING:tensorflow:Can save best model only with val_auc available, skipping.
# 219/219 [==============================] - 4s 20ms/step - loss: 0.3998 - auc_3: 0.9486 - accuracy: 0.8793 - val_loss: 0.4910 - val_auc_3: 0.9180 - val_accuracy: 0.8525
# Training took 960.94 sec

# %%
def learning_curves(history):
    """
    Plot the learning curves of loss and macro f1 score 
    for the training and validation datasets.
    
    Args:
        history: history callback of fitting a tensorflow keras model 
    """
    
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    
    try:
        auc = history.history['auc_1']
        val_auc = history.history['val_auc_1']
    except:
        pass
    try:
        auc = history.history['auc_2']
        val_auc = history.history['val_auc_2']
    except:
        pass
    try:
        auc = history.history['auc_3']
        val_auc = history.history['val_auc_3']
    except:
        pass
        
    
    epochs = len(loss)

    style.use("bmh")
    plt.figure(figsize=(8, 8))

    plt.subplot(3, 1, 1)
    plt.tight_layout(h_pad=2)

    plt.plot(range(1, epochs+1), loss, label='Training Loss')
    plt.plot(range(1, epochs+1), val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')

    plt.subplot(3, 1, 2)
    plt.plot(range(1, epochs+1), accuracy, label='Training Accuracy')
    plt.plot(range(1, epochs+1), val_accuracy, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('accuracy')
    plt.title('Training and Validation accuracy')
    # plt.xlabel('epoch')
    
    plt.subplot(3, 1, 3)
    plt.plot(range(1, epochs+1), auc, label='Training AUC')
    plt.plot(range(1, epochs+1), val_auc, label='Validation AUC')
    plt.legend(loc='lower right')
    plt.ylabel('AUC')
    plt.title('Training and Validation AUC')
    plt.xlabel('epoch')

    plt.show()
    
    return loss, val_loss, accuracy, val_accuracy, auc, val_auc

# %%
loss, val_loss, accuracy, val_accuracy, auc_2, val_auc_2 = learning_curves(history)

# %%
print(f"Best validation accuracy maximum : {np.round(np.max(history.history['val_accuracy']), 3)}.")
print(f"Best validation AUC maximum : {np.round(np.max(history.history['val_auc_3']), 3)}.")
# Out:
# Best validation accuracy maximum : 0.88.
# Best validation AUC maximum : 0.951.

# %% [markdown]
# **We keep the model having the best auc score.**

# %%
loaded_predictions = model.predict(val_ds)

# %%
print(f"Final AUC on the validation set : {np.round(np.max(history.history['val_auc_3']), 3)}.")
print(f"Final accuracy on the validation set : {(y_val==(loaded_predictions>.5).flatten()).sum()*100/len(y_val)}%.")
# Out:
# Final AUC on the validation set : 0.951.
# Final accuracy on the validation set : 85.25%.

# %% [markdown]
# ### Save

# %%
# Save the entire model as a SavedModel.
# !mkdir -p saved_model
model.save('models/classification_model')
# Out:
# INFO:tensorflow:Assets written to: saved_model/my_model/assets

# %% [markdown]
# ### Load

# %%
new_model = tf.keras.models.load_model('saved_model/my_model')

# %%
# Evaluate the model
loss, auc, acc = new_model.evaluate(val_ds, verbose=2)
print("Model accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 13/13 - 0s - loss: 0.5683 - auc_2: 0.9174 - accuracy: 0.8475 - 183ms/epoch - 14ms/step
# Model accuracy: 84.75%
